# %%
from PIL import Image

# %%
im1=Image.open(r"C:\Users\admin\Downloads\kuva.png")
imgray=im1.convert('L')
imbinary=im1.convert('1')
im1.show()
imgray.show()
imbinary.show()

# %% [markdown]
# ![Screenshot 2021-06-01 184026.jpg](attachment:736044f7-e1dc-4489-963a-ccd28b63976c.jpg)

# %% [markdown]
# ![Screenshot 2021-06-01 184153.jpg](attachment:4a8aefb3-b467-4764-b628-65e9f4aefcc0.jpg)

# %% [markdown]
# ![Screenshot 2021-06-01 184231.jpg](attachment:ff01be4b-39e1-4d5a-802c-fc4c02f25fd0.jpg)
